# %%
import matplotlib.pylab as plt
from numpy import *

# %%
y = lambda w: tan(400000*w)-tan(1600000*w/(3-(400000*w)**2))
w = linspace(0,5,100)
plt.plot(w,y(w))

# %%
y2 = lambda w: sqrt(((2*(5+(4000000/w)))**2 + (800000*w*(5+(4000000/w)))**2)/((3-(400000*w)**2)**2 + (1600000*w)**2))
plt.plot(w,y2(w))
# Out:
# /Users/usuario/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   """Entry point for launching an IPython kernel.
# /Users/usuario/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in multiply
#   """Entry point for launching an IPython kernel.

# %%
a=(20-0.7-50000-(10-0.7)*10000)/5000
(10-a)/5000
# Out:
# 0.007719228000000001

# %%
10-(9.3/5000)
# Out:
# 9.99814

# %%
0.7-10-(10/10000)
# Out:
# -9.301
